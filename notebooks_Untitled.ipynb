# %%
import numpy as np

# %%
a= np.array([1,2,3],dtype='int32')
print(a)
b=np.array([[9.0,8.0,7],[6.0,5.0,4.0]])
print(b)
# Out:
# [1 2 3]
# [[9. 8. 7.]
#  [6. 5. 4.]]

# %%
a.ndim
# Out:
# 1

# %%
b.shape
# Out:
# (2, 3)

# %%
#get type
a.dtype
# Out:
# dtype('int32')

# %%
#byte size of 1 element 
a.itemsize
b.itemsize
# Out:
# 8

# %%
#total byte size
a.size * a.itemsize
# Out:
# 12

# %%
#INDEXING AND SLICING
